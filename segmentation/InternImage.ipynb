# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab')
# Out:
# Mounted at /content/drive

# %%
# %cd InternImage
# Out:
# /content/drive/MyDrive/Colab/InternImage

# %%
# !pip install -U openmim
# !mim install mmcv-full==1.5.0
# !pip install timm==0.6.11 mmdet==2.28.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 KB 1.5 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu116/torch1.13.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.8/530.8 KB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 22.1 MB/s eta 0:00:00
# ...
#   Created wheel for mmcv-full: filename=mmcv_full-1.5.0-cp39-cp39-linux_x86_64.whl size=27209771 sha256=43868b4759b0b40fb3798052d36b23fb7dcc383ef20f9d83533ff63da299d3d4
# ...

# %%
# !pip install opencv-python termcolor yacs pyyaml scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd ops_dcnv3
# !sh make.sh
# unit test (should see all checking is True)
#!python test.py
# Out:
# /content/drive/MyDrive/Colab/InternImage/ops_dcnv3
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab/InternImage/ops_dcnv3/setup.py", line 73, in <module>
#     ext_modules=get_extensions(),
#   File "/content/drive/MyDrive/Colab/InternImage/ops_dcnv3/setup.py", line 46, in get_extensions
#     raise NotImplementedError('Cuda is not availabel')
# NotImplementedError: Cuda is not availabel

# %%
#!python test.py configs/cityscapes/upernet_internimage_xl_512x1024_160k_mapillary2cityscapes.py checkpoint/cityscapes.pth --eval mIoU

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Colab/InternImage

# %%
# !pip3 install mmsegmentation
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.7/831.7 KB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.8/648.8 KB 44.6 MB/s eta 0:00:00
# ...

# %%
#跑前修改demo文件中默認路徑
#imshow can't run on colab.Please use plt and save the picture for checking.
# !CUDA_VISIBLE_DEVICES=0 python vedio_test.py --palette cityscapes
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab/InternImage/vedio_test.py", line 6, in <module>
#     import mmseg_custom  # noqa: F401,F403
#   File "/content/drive/MyDrive/Colab/InternImage/mmseg_custom/__init__.py", line 7, in <module>
#     from .models import *  # noqa: F401,F403
#   File "/content/drive/MyDrive/Colab/InternImage/mmseg_custom/models/__init__.py", line 7, in <module>
#     from .backbones import *  # noqa: F401,F403
#   File "/content/drive/MyDrive/Colab/InternImage/mmseg_custom/models/backbones/__init__.py", line 7, in <module>
#     from .intern_image import InternImage
#   File "/content/drive/MyDrive/Colab/InternImage/mmseg_custom/models/backbones/intern_image.py", line 17, in <module>
#     from ops_dcnv3 import modules as opsm
#   File "/content/drive/MyDrive/Colab/InternImage/ops_dcnv3/modules/__init__.py", line 7, in <module>
# ...

# %%
#image_demo
import cv2
import matplotlib.pyplot as plt
out = cv2.imread('output1.jpg')
plt.figure(figsize=(10,5))
plt.imshow(out)
